# %% [markdown]
# ![표지](표지.png)

# %% [markdown]
# -------------
# ## 목차
# 1. 주피터 사용법
# 2. 파이썬 기초
# 3. 개발과정
# 4. 웹의 이해
# 5. 네이버 영화 리뷰 크롤러 만들기

# %% [markdown]
# --------------------
# ### 2. 파이썬 기초
# * <b>문자열, 숫자</b>: url, page 번호 등 변수를 저장할 때 활용
# * <b>몫/나머지 연산</b>: 전체 페이지 수 구할 때 활용
# * <b>리스트 삽입 연산</b>: 크롤링한 데이터를 저장할 때 활용
# * <b>제어문(if문)</b>: 데이터가 제대로 크롤링되었는지 확인할 때 활용
# * <b>반복분(for문)</b>: 데이터를 반복적으로 크롤링할 때 활용

# %% [markdown]
# #### 2-1 문자열, 숫자
# * <b>문자열</b>: 숫자가 아닌 문자를 뜻하며 양쪽 끝에 "로 묶어 선언
# * <b>숫자</b>: 정수, 소수 등 다양한 숫자가 존재하지만 여기서는 정수 형태만 알면 됨
# * <b>type()</b>: 데이터와 자료구조의 형태를 출력
#    - 'str': 문자 / 'int': 숫자(정수)

# %%
url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=167605&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
page_number = 1
print("URL:{}\n글자수:{}".format(url, page_number))
print("URL의 타입: {}\npage_number의 타입: {}".format(type(url), type(page_number)))
print("숫자 데이터에 따옴표로 양쪽 끝을 묶으면 문자열이 된다.")
page_string = "1"
print("page_string 타입: {}".format(type(page_string)))
# Out:
# URL:https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=167605&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# 글자수:1
# URL의 타입: <class 'str'>
# page_number의 타입: <class 'int'>
# 숫자 데이터에 따옴표로 양쪽 끝을 묶으면 문자열이 된다.
# page_string 타입: <class 'str'>

# %% [markdown]
# #### 2-2 몫/나머지 연산
# * <b>나머지 연산자</b>: %
# * <b>몫 연산자</b>: //

# %%
count_tmp = 4896
print("전체 리뷰수는 총 {} 건이며, 전체 페이지 수는 {}이다.".format(count_tmp,count_tmp//10))
# Out:
# 전체 리뷰수는 총 4896 건이며, 전체 페이지 수는 489이다.

# %% [markdown]
# #### 2-3 리스트 삽입 연산
# * <b>자료구조</b>: 데이터를 효율적으로 활용하기 위해 만든 데이터의 저장소
# * <b>리스트</b>: 데이터를 배열 형태로 저장한 자료구조
# * <b>list(), []</b>: 리스트 자료형태를 만듦
# * <b>리스트명[i]</b>: i번째 데이터에 접근 // 리스트는 0부터 시작
# * <b>append</b>: 리스트 끝에 데이터를 삽입하는 메서드

# %%
column_name = ['date','user','comment','score','likes']
print(column_name, type(column_name))
# Out:
# ['date', 'user', 'comment', 'score', 'likes'] <class 'list'>

# %%
column_name[0]
# Out:
# 'date'

# %%
column_name.append("dislikes")
print(column_name)
# Out:
# ['date', 'user', 'comment', 'score', 'likes', 'dislikes']

# %% [markdown]
# #### 2-4 제어문(if문)
# * 엑셀의 if함수와 기능이 동일
# * if 조건:
#         참일 때 연산
#   else:
#         거짓일 때 연산

# %%
count_tmp = 4896
if count_tmp%10!=0:
    page_tmp = count_tmp//10+1
    print(page_tmp)
else:
    page_tmp = content_tmp//10
    print(page_tmp)
# Out:
# 490

# %% [markdown]
# #### 2-5 반복문(for문)
# * 동일한 연산을 개발자가 정해준 횟수만큼 반복
# * for i in range(시작, 끝):
#     시작부터 끝에서 1을 뺀 숫자만큼 반복
#     예: range(0,10) -> 0부터 9까지 // 컴퓨터는 대부분 0부터 시작

# %%
score_tmp = [10,10,9,10,10,10,9,9,10,10]
for i in range(0,len(score_tmp)):
    print("{}번째 점수는 {}입니다.".format(i, score_tmp[i]))
# Out:
# 0번째 점수는 10입니다.
# 1번째 점수는 10입니다.
# 2번째 점수는 9입니다.
# 3번째 점수는 10입니다.
# 4번째 점수는 10입니다.
# 5번째 점수는 10입니다.
# 6번째 점수는 9입니다.
# 7번째 점수는 9입니다.
# 8번째 점수는 10입니다.
# 9번째 점수는 10입니다.

# %% [markdown]
# -------------------
# ### 4. 웹의 이해
# * <b>서버와 클라이언트</b>
# * <b>URL구조</b>
# * <b>HTML5 / CSS3 / Javascript</b>

# %% [markdown]
# #### 4.1 서버와 클라이언트
# * <b>클라이언트</b>: IT에서 클라이언트는 데이터, 서비스를 요청하는 프로그램
# [예] 웹 브라우저(크롬, 익스플로러), 어플리케이션(카카오톡, 라인 등)
# * <b>서버</b>: 인터넷을 통해 연결된 클라이언트에 데이터 또는 서비스를 제공하는 프로그램

# %% [markdown]
# <img src="서버와 클라이언트.png" width="400" height="300">

# %% [markdown]
# <center> <b>point.특정 페이지를 크롤링하기 위해서는 서버에 페이지요청을 해야 한다!</b></center>

# %%
# 페이지 요청을 보내는 모듈
import requests

# %%
url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=167605&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"

response = requests.get(url)
html = response.text
html
# Out:
# '\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n<meta charset="utf-8">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<title>네이버 영화</title>\r\n\n\n\n\t\n\t\n\t\n\t\n\t\t<link rel="shortcut icon" href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" type="image/x-icon">\n\t\t\t\n\n\r\n\n<link rel="stylesheet" type="text/css" href="/css/common.css?20200212150141" />\r\n\n<link rel="stylesheet" type="text/css" href="/css/movie_tablet.css?20200212150141" />\n<link rel="stylesheet" type="text/css" href="/css/movie_end.css?20200212150141" />\r\n\r\n\n\n\n<script type="text/javascript" src="/js/deploy/movie.all.js?20200212150141"></script>\n\n\n\r\n</head>\r\n<body>\r\n\t<!-- content -->\r\n<input type="hidden" name="movieCode" id="movieCode" value="167605"/>\r\n<input type="hidden" name="onlyActualPointYn" id="onlyActualPointYn" value="N"/>\r\n<input type="hidden" name="includeSpoilerYn" id="includeSpoilerYn" value="N"/>\r\n<input type="
# ...

# %% [markdown]
# #### 4.2 URL 구조
# <img src="url구조.png">
# <center> <b>쿼리스트링: 클라이언트가 서버에 보내는 데이터로 ?뒤에 나오는 모든 문자</b></center>

# %% [markdown]
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=167605&type=after&isActualPointWriteExecute=false&isMil"eageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# <b>경로</b>:https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn
# <b>쿼리스티링</b>:code=167605&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&<b>page=1</b>

# %%
url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=167605&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page="
for i in range(1, 3):
    response = requests.get(url)
    html = response.text
    print(html)
    print("-"*100)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <title>네이버 영화</title>
#
#
#
#
#
#
#
# 		<link rel="shortcut icon" href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" type="image/x-icon">
#
#
#
#
# <link rel="stylesheet" type="text/css" href="/css/common.css?20200212150141" />
#
# <link rel="stylesheet" type="text/css" href="/css/movie_tablet.css?20200212150141" />
# <link rel="stylesheet" type="text/css" href="/css/movie_end.css?20200212150141" />
#
#
#
#
# <script type="text/javascript" src="/js/deploy/movie.all.js?20200212150141"></script>
#
#
#
# </head>
# <body>
# 	<!-- content -->
# <input type="hidden" name="movieCode" id="movieCode" value="167605"/>
# <input type="hidden" name="onlyActualPointYn" id="onlyActualPointYn" value="N"/>
# <input type="hidden" name="includeSpoilerYn" id="includeSpoilerYn" value="N"/>
# ...

# %% [markdown]
# #### 4.3.1 HTML/CSS/JavaScript 이해
# <img style="float: left;" src="표.png" width="320" height="200">

# %% [markdown]
# #### 4.3.2 CSS - id와 class 이해
# * 배경: 뼈대를 만들고 디자인을 효율적으로 적용하기 위해 만들어짐
# * <b>id</b>: 특정한 곳에 디자인을 적용할 때 사용(유일한 값)
# * <b>class</b>: 비슷한 패턴에 동일한 디자인을 적용할 때 사용

# %% [markdown]
# #### 4.3.2 CSS 선택자 이해(실습)
# <img src="css선택자.png" width="1000" height="500">

# %%
# 데이터를 파싱할 수 있는 모듈
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# %%
# 전체 리뷰 수 파싱
soup.select(".score_total > .total > em")[0].get_text()
# Out:
# '10,506'

# %%
# 첫번째 리뷰 내용 파싱
print("날짜: {}".format(soup.select(".score_reple > dl > dt > em:nth-of-type(2)")[0].get_text()))
print("유저: {}".format(soup.select(".score_reple > dl > dt > em > a > span")[0].get_text()))
print("코멘트: {}".format(soup.select(".score_reple > p > span")[0].get_text().strip()))
print("평점: {}".format(soup.select(".star_score em")[0].get_text()))
print("공감: {}".format(soup.select("._sympathyButton > strong")[0].get_text()))
print("비공감: {}".format(soup.select("._notSympathyButton > strong")[0].get_text()))
# Out:
# 날짜: 2019.10.30 10:33
# 유저: 도도(uoqv****)
# 코멘트: 액션이랑 스케일 다 미쳤음! 갓밀러 감독님 믿보!!
# 평점: 10
# 공감: 1560
# 비공감: 161

# %% [markdown]
# ### 6. 터미네이터 리뷰크롤러 만들기

# %%
# 1단계: URL 접속하고 파싱 개체 만들기
import requests
from bs4 import BeautifulSoup
url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=167605&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page="
respons = requests.get(url)
html = respons.text
soup = BeautifulSoup(html, 'html.parser')

# %%
# 2단계: 페이지 개수 구하기
import re
review_count = int(re.sub(",","",soup.select(".total em")[0].get_text()))
if review_count%10!=0:
    page = review_count//10+1
    print(page)
else:
    page = review_count//10
    print(page)
# Out:
# 1051

# %%
# 3단계: 자료구조를 선언하고 데이터 추가하기
import time
from tqdm

review = list()

for p in tqdm(range(1,page+1),desc="Page"):
    response = requests.get(url+str(p))
    html = response.text
    soup = BeautifulSoup(html,'html.parser')
    try:
        for i in range(10):
            date = re.sub("\.","-",soup.select(".score_reple > dl > dt > em:nth-of-type(2)")[i].get_text())
            user = soup.select(".score_reple > dl > dt > em > a > span")[i].get_text()
            comment = soup.select(".score_reple > p > span")[i].get_text().strip()
            score = int(soup.select(".star_score em")[i].get_text())
            likes = int(soup.select("._sympathyButton > strong")[i].get_text())
            dislikes = int(soup.select("._notSympathyButton > strong")[i].get_text())
            review_tmp = [date, user, comment, score, likes, dislikes]
            if len(review_tmp)==6:
                review.append(review_tmp)
            else:
                review.append("오류","오류","오류","오류","오류","오류","오류")
    except:
        review.append("오류","오류","오류","오류","오류","오류","오류")
        continue
    time.sleep(1)

# %%
# 4단계: 데이터 확인하기
review[0], len(review)

# %%
# 5단계: 데이터 변환
import pandas as pd
df_review = pd.DataFrame(review, columns = ['date','user','comment','score','likes','dislikes'])
df_review['date'] = pd.to_datetime(df_review['date'])
df_review.head()

# %%
# 6단계: 데이터 저장
from datetime import datetime
now = datetime.today()
str(now.strftime("%Y%m%d"))
df_review.to_excel(str(now.strftime("%Y%m%d"))+"_터미네이터_영화리뷰.xlsx", encoding = 'utf-8')
